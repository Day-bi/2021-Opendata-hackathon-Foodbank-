# %%
import requests, xmltodict, json

#발급받은 키
key = "n3ShZ50BH%2B3BPRnQ0wD0PnX5YxJEoWTOXt7N3GzQN2fkAPCjMLTpo%2FqxHfIW%2FWI344oDzIiTaQJ5ratuQfJOGQ%3D%3D"
#stdYm = 년도 월, numOfRows = 총 데이터 양
url = "http://apis.data.go.kr/B460014/foodBankInfoService2/getCntrbtrInfo?serviceKey={}".format(key)+"&stdrYm=202001&numOfRows=10000&pageNo=1"

content = requests.get(url).content

dic = xmltodict.parse(content)
jsonString = json.dumps(dic['response']['body'], ensure_ascii = False)
jsonObj = json.loads(jsonString)

# %%
body = jsonObj['items']['item']

import pandas as pd
from pandas.io.json import json_normalize
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

pd.set_option('display.max_rows', None)

df = json_normalize(body)

# %%
# 기업(개인사업자) : 01
# 단체 : 02
# 개인 : 03
done_df = df[['cntrbtrSeccd']]
print(done_df.tail(5))
# Out:
#      cntrbtrSeccd
# 6068           02
# 6069           03
# 6070           01
# 6071           01
# 6072           01
#    stdrYm areaCd unitySignguCd spctrCd cntrbtrSeccd cntrBplcKndcd  \
# 0  202001     01      01000000  S00101           01            01
# 1  202001     01      01000000  S00101           01            01
# 2  202001     01      01000000  S00101           01            01
# 3  202001     01      01000000  S00101           01            01
# 4  202001     01      01000000  S00101           01            01
#
#           cntrbtrNm    cntrAmt cntrCo cntrbtrCo
# 0             (주)농심  190844980      3         1
# 1           광동제약(주)   23832000      1         1
# 2           남양유업(주)  182488290      4         1
# 3  농업회사법인 주식회사 프레쉬벨  107381000      2         1
# 4             대상(주)  239162856     17         1

# %%
import urllib.request
import urlopen
from time import localtime, strftime

# %%
# 연도별
index = pd.date_range(start='20200101', end = '20201231')
df_list = index.strftime("%Y%m").tolist()

for i in df_list:
    url = "http://apis.data.go.kr/B460014/foodBankInfoService2/getCntrbtrInfo?serviceKey={}".format(key)+"&stdrYm="+i
    reponse = urllib.request.urlopen()
    jsosn_str = reponse.read().decode("utf-8")
    json_object = json.loads(json_str)
    df_temp = pd.json_normaliae(json_object['stdrYm','cntrbtrSeccd','cntrbtrCo'])
    df_2020 = df.append(df_temp)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\Anaconda3\envs\competi\lib\site-packages\dateutil\parser\_parser.py in parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     654         try:
# --> 655             ret = self._build_naive(res, default)
#     656         except ValueError as e:
#
# ~\Anaconda3\envs\competi\lib\site-packages\dateutil\parser\_parser.py in _build_naive(self, res, default)
#    1240
# -> 1241         naive = default.replace(**repl)
#    1242
#
# ValueError: month must be in 1..12
#
# The above exception was the direct cause of the following exception:
#
# ParserError                               Traceback (most recent call last)
# pandas\_libs\tslibs\conversion.pyx in pandas._libs.tslibs.conversion._convert_str_to_tsobject()
#
# pandas\_libs\tslibs\parsing.pyx in pandas._libs.tslibs.parsing.parse_datetime_string()
#
# ...

# %%
url = "http://apis.data.go.kr/B460014/foodBankInfoService2/getCntrbtrInfo?serviceKey={}".format(key)+"&stdrYm=202001&numOfRows=10000&pageNo=1"

content = requests.get(url).content

dic = xmltodict.parse(content)
jsonString = json.dumps(dic['response']['body'], ensure_ascii = False)
jsonObj = json.loads(jsonString)

body = jsonObj['items']['item']

df = json_normalize(body)
done_df1 = df[['stdrYm','cntrbtrSeccd','cntrbtrCo']]
#
url = "http://apis.data.go.kr/B460014/foodBankInfoService2/getCntrbtrInfo?serviceKey={}".format(key)+"&stdrYm=202002&numOfRows=10000&pageNo=1"

content = requests.get(url).content

dic = xmltodict.parse(content)
jsonString = json.dumps(dic['response']['body'], ensure_ascii = False)
jsonObj = json.loads(jsonString)

body = jsonObj['items']['item']

df = json_normalize(body)
done_df2 = df[['stdrYm','cntrbtrSeccd','cntrbtrCo']]
t = done_df1.append(done_df2)
#
url = "http://apis.data.go.kr/B460014/foodBankInfoService2/getCntrbtrInfo?serviceKey={}".format(key)+"&stdrYm=202003&numOfRows=10000&pageNo=1"

content = requests.get(url).content

dic = xmltodict.parse(content)
jsonString = json.dumps(dic['response']['body'], ensure_ascii = False)
jsonObj = json.loads(jsonString)

body = jsonObj['items']['item']

df = json_normalize(body)
done_df3 = df[['stdrYm','cntrbtrSeccd','cntrbtrCo']]
t = t.append(done_df3)
#
url = "http://apis.data.go.kr/B460014/foodBankInfoService2/getCntrbtrInfo?serviceKey={}".format(key)+"&stdrYm=202004&numOfRows=10000&pageNo=1"

content = requests.get(url).content

dic = xmltodict.parse(content)
jsonString = json.dumps(dic['response']['body'], ensure_ascii = False)
jsonObj = json.loads(jsonString)

body = jsonObj['items']['item']

df = json_normalize(body)
done_df4 = df[['stdrYm','cntrbtrSeccd','cntrbtrCo']]
t = t.append(done_df4)
#
url = "http://apis.data.go.kr/B460014/foodBankInfoService2/getCntrbtrInfo?serviceKey={}".format(key)+"&stdrYm=202005&numOfRows=10000&pageNo=1"

content = requests.get(url).content

dic = xmltodict.parse(content)
jsonString = json.dumps(dic['response']['body'], ensure_ascii = False)
jsonObj = json.loads(jsonString)

body = jsonObj['items']['item']

df = json_normalize(body)
done_df5 = df[['stdrYm','cntrbtrSeccd','cntrbtrCo']]
t = t.append(done_df5)
#
url = "http://apis.data.go.kr/B460014/foodBankInfoService2/getCntrbtrInfo?serviceKey={}".format(key)+"&stdrYm=202006&numOfRows=10000&pageNo=1"

content = requests.get(url).content

dic = xmltodict.parse(content)
jsonString = json.dumps(dic['response']['body'], ensure_ascii = False)
jsonObj = json.loads(jsonString)

body = jsonObj['items']['item']

df = json_normalize(body)
done_df6 = df[['stdrYm','cntrbtrSeccd','cntrbtrCo']]
t = t.append(done_df6)
#

url = "http://apis.data.go.kr/B460014/foodBankInfoService2/getCntrbtrInfo?serviceKey={}".format(key)+"&stdrYm=202007&numOfRows=10000&pageNo=1"

content = requests.get(url).content

dic = xmltodict.parse(content)
jsonString = json.dumps(dic['response']['body'], ensure_ascii = False)
jsonObj = json.loads(jsonString)

body = jsonObj['items']['item']

df = json_normalize(body)
done_df7 = df[['stdrYm','cntrbtrSeccd','cntrbtrCo']]
t = t.append(done_df7)
#

url = "http://apis.data.go.kr/B460014/foodBankInfoService2/getCntrbtrInfo?serviceKey={}".format(key)+"&stdrYm=202008&numOfRows=10000&pageNo=1"

content = requests.get(url).content

dic = xmltodict.parse(content)
jsonString = json.dumps(dic['response']['body'], ensure_ascii = False)
jsonObj = json.loads(jsonString)

body = jsonObj['items']['item']

df = json_normalize(body)
done_df8 = df[['stdrYm','cntrbtrSeccd','cntrbtrCo']]
t = t.append(done_df8)
#


url = "http://apis.data.go.kr/B460014/foodBankInfoService2/getCntrbtrInfo?serviceKey={}".format(key)+"&stdrYm=202009&numOfRows=10000&pageNo=1"

content = requests.get(url).content

dic = xmltodict.parse(content)
jsonString = json.dumps(dic['response']['body'], ensure_ascii = False)
jsonObj = json.loads(jsonString)

body = jsonObj['items']['item']

df = json_normalize(body)
done_df9 = df[['stdrYm','cntrbtrSeccd','cntrbtrCo']]
t = t.append(done_df9)
#

url = "http://apis.data.go.kr/B460014/foodBankInfoService2/getCntrbtrInfo?serviceKey={}".format(key)+"&stdrYm=202010&numOfRows=10000&pageNo=1"

content = requests.get(url).content

dic = xmltodict.parse(content)
jsonString = json.dumps(dic['response']['body'], ensure_ascii = False)
jsonObj = json.loads(jsonString)

body = jsonObj['items']['item']

df = json_normalize(body)
done_df10 = df[['stdrYm','cntrbtrSeccd','cntrbtrCo']]
t = t.append(done_df10)
#


url = "http://apis.data.go.kr/B460014/foodBankInfoService2/getCntrbtrInfo?serviceKey={}".format(key)+"&stdrYm=202011&numOfRows=10000&pageNo=1"

content = requests.get(url).content

dic = xmltodict.parse(content)
jsonString = json.dumps(dic['response']['body'], ensure_ascii = False)
jsonObj = json.loads(jsonString)

body = jsonObj['items']['item']

df = json_normalize(body)
done_df11 = df[['stdrYm','cntrbtrSeccd','cntrbtrCo']]
t = t.append(done_df11)
#

url = "http://apis.data.go.kr/B460014/foodBankInfoService2/getCntrbtrInfo?serviceKey={}".format(key)+"&stdrYm=202012&numOfRows=10000&pageNo=1"

content = requests.get(url).content

dic = xmltodict.parse(content)
jsonString = json.dumps(dic['response']['body'], ensure_ascii = False)
jsonObj = json.loads(jsonString)

body = jsonObj['items']['item']

df = json_normalize(body)
done_df12 = df[['stdrYm','cntrbtrSeccd','cntrbtrCo']]
t = t.append(done_df12)

# %%
t.to_csv("t.csv") # 기부년월, 기부자(기업,단체,개인),기부건수
